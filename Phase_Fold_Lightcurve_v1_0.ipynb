# %%
LIGHTCURVE = '102912369'

# %% [markdown]
# # Carregando uma curva de luz

# %%
# !pip install /content/imt_lightcurve-1.2-py3-none-any.whl

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from imt_lightcurve.models.lightcurve import LightCurve

# Chosen a LightCurve to simulation process


curve_id = int(LIGHTCURVE)

# Importing lightcurve data from github
data = pd.read_csv('https://raw.githubusercontent.com/Guilherme-SSB/IC-CoRoT_Kepler/main/resampled_files/' + LIGHTCURVE + '.csv')
flux = data.WHITEFLUX.to_numpy()
time = np.arange(0, len(flux))

curve = LightCurve(time, flux)
curve.plot()

P = LightCurve.get_true_value(curve_id, 'Per')
print(f'Period is {round(P, 4)} days')
# Out:
#   <div class="bk-root" id="7b9a76ac-7ca0-4456-95f2-41118ae1a0c9" data-root-id="1124"></div>
# Period is 9.2015 days

# %%
filtered = curve.butterworth_lowpass_filter(6, 0.1)
filtered.view_filtering_results()
# Out:
#   <div class="bk-root" id="123425d9-596b-4702-b08d-e703ed660a89" data-root-id="3145"></div>

# %%
curve.fold(LIGHTCURVE).plot('LC folded raw')
# Out:
#   <div class="bk-root" id="2fc1b5b6-50f9-4bfe-a1f6-5d9a0f510e85" data-root-id="4511"></div>

# %%
curve_aux = LightCurve(filtered.time, filtered.filtered_flux)
curve_aux.fold(LIGHTCURVE).plot('LC folded filtered')
# Out:
#   <div class="bk-root" id="200ac87b-78fd-4a05-b396-151daca169cb" data-root-id="4214"></div>
